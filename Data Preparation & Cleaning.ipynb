# %% [markdown]
# # Libraries needed

# %%
import requests
import json
import pandas as pd
import time

# %% [markdown]
# # MyAnimeList (MAL) API Documentation
# https://myanimelist.net/apiconfig/references/api/v2

# %% [markdown]
# # Check if API is working

# %%
url = 'https://api.myanimelist.net/v2/anime'
headers={'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsImp0aSI6ImUyNWEyZWNlNzFkZWUzYjFlNmNkMWQ5OTJjNWQ3Y2JiNTk2ZDUzYzRiZGU5NjRkODg1NzhhYTE3NDY0MGQzMDUzNmQyYzhiOWRlMmU0NDdhIn0..ewvdwjyXaPgPczBACG-RnlkLFB32GNMkObEqkJgzWKK4cTWme2cCZ6aCyQYhhSHkQbeqHpP_wtFhBLKYN3L1zalJIgo582TuckRtQLm3kR7e_kzGAK5TFYwDjxdUaURLdQGeRgVRmAHPdlvA6BNpae4iKVmExLSvlkcIXlSGKkYnQHNpN51YpHp2T13PB4lTJYo9PoPOyv-Vf1oRrlhMlr6YFR0jX3jzhZthM-tkSYI3eRCC4uqF22hTD_33VY7j3kwJBtBK9ngdMK-LBftgDtKDWB8wcpfWoOh5bX9l7w9S5dXUuhkF8KlZZWlzToc4c8hjmR2MxsieDfi69QKsOA'}
params = {'q': 'one', 'limit': 1}
response = requests.get(url,headers=headers, params=params)
print("Reponse status code:", response.status_code)
if response.status_code == 200:
    print('API is working.')
else:
    print('API is not working.')
# Out:
# Reponse status code: 200
# API is working.

# %% [markdown]
# # Choose which GET Request to use from MAL API Documentation to get the whole anime dataset
# Both GET Request for anime ranking and seasonal anime will be able to provide a whole dataset of all animes available. Anime rankings is chosen as it is easier to loop in batches of 500 using the 'offset' parameter.

# %% [markdown]
# # GET anime ranking API
# Based on the MAL API Documentation, some parameters for GET anime ranking would include:
#
# -ranking_type: all -> To get all the top anime series
#
# -limit: 500 (max) -> To get more data per request
#
# -offset: (used later to get the entire database)
#
# -fields: id,title,main_picture,alternative_titles,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,pictures,background,related_anime,related_manga,recommendations,studios,statistics
# (This field is given from GET anime details, assuming query parameter is the same for GET anime ranking)

# %%
url = 'https://api.myanimelist.net/v2/anime/ranking'
headers = {'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsImp0aSI6ImUyNWEyZWNlNzFkZWUzYjFlNmNkMWQ5OTJjNWQ3Y2JiNTk2ZDUzYzRiZGU5NjRkODg1NzhhYTE3NDY0MGQzMDUzNmQyYzhiOWRlMmU0NDdhIn0..ewvdwjyXaPgPczBACG-RnlkLFB32GNMkObEqkJgzWKK4cTWme2cCZ6aCyQYhhSHkQbeqHpP_wtFhBLKYN3L1zalJIgo582TuckRtQLm3kR7e_kzGAK5TFYwDjxdUaURLdQGeRgVRmAHPdlvA6BNpae4iKVmExLSvlkcIXlSGKkYnQHNpN51YpHp2T13PB4lTJYo9PoPOyv-Vf1oRrlhMlr6YFR0jX3jzhZthM-tkSYI3eRCC4uqF22hTD_33VY7j3kwJBtBK9ngdMK-LBftgDtKDWB8wcpfWoOh5bX9l7w9S5dXUuhkF8KlZZWlzToc4c8hjmR2MxsieDfi69QKsOA'}
params = {'ranking_type': 'all',
          'limit': 500,
          'fields': 'id,title,main_picture,alternative_titles,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,pictures,background,related_anime,related_manga,recommendations,studios,statistics'}
response = requests.get(url, headers=headers, params=params)
anime_data = response.json()['data']
print("Columns available:")
for column in anime_data[0]['node'].keys():
    print(column)
# Out:
# Columns available:
# id
# title
# main_picture
# alternative_titles
# start_date
# end_date
# synopsis
# mean
# rank
# popularity
# num_list_users
# num_scoring_users
# nsfw
# created_at
# updated_at
# media_type
# status
# genres
# num_episodes
# start_season
# source
# average_episode_duration
# rating
# studios

# %% [markdown]
# # Comparing the information obtained from GET anime ranking and GET anime details
# Statistics such as watching, completed, on-hold, dropped, planned-to-watch which are useful but not provided in GET anime ranking.
# As those information are useful, GET anime details is used to obtain the dataset.

# %% [markdown]
# # Using GET anime ranking to get a list of all anime IDs

# %%
anime_list = []
url = 'https://api.myanimelist.net/v2/anime/ranking'
headers = {'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsImp0aSI6ImUyNWEyZWNlNzFkZWUzYjFlNmNkMWQ5OTJjNWQ3Y2JiNTk2ZDUzYzRiZGU5NjRkODg1NzhhYTE3NDY0MGQzMDUzNmQyYzhiOWRlMmU0NDdhIn0..ewvdwjyXaPgPczBACG-RnlkLFB32GNMkObEqkJgzWKK4cTWme2cCZ6aCyQYhhSHkQbeqHpP_wtFhBLKYN3L1zalJIgo582TuckRtQLm3kR7e_kzGAK5TFYwDjxdUaURLdQGeRgVRmAHPdlvA6BNpae4iKVmExLSvlkcIXlSGKkYnQHNpN51YpHp2T13PB4lTJYo9PoPOyv-Vf1oRrlhMlr6YFR0jX3jzhZthM-tkSYI3eRCC4uqF22hTD_33VY7j3kwJBtBK9ngdMK-LBftgDtKDWB8wcpfWoOh5bX9l7w9S5dXUuhkF8KlZZWlzToc4c8hjmR2MxsieDfi69QKsOA'}
params = {'ranking_type': 'all', 'limit': 500}

for offset in range(0, 100000, 500):
    params['offset'] = offset
    response = requests.get(url, headers=headers, params=params)
    data = response.json()['data']
    if data:
        anime_list.extend(data)
    else:
        break

anime_ids = [anime['node']['id'] for anime in anime_list]
unique_anime_ids = set(anime_ids)
print("Number of items in list:", len(anime_ids))
print("Number of unique animes:", len(unique_anime_ids))
print(anime_ids)
# Out:
# Number of items in list: 24095
# Number of unique animes: 24095
# ...

# %% [markdown]
# # Using GET anime details with anime_ids list to obtain full anime dataset with all information
# The GET anime detail can only retrieve data for each anime ID and that counts as a single request each time. There is a need to delay each request to not hit API request limit.
# # *The cell below will take a VERY long time to run* 1 second delay for each request

# %%
anime_details = []
headers = {'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsImp0aSI6ImUyNWEyZWNlNzFkZWUzYjFlNmNkMWQ5OTJjNWQ3Y2JiNTk2ZDUzYzRiZGU5NjRkODg1NzhhYTE3NDY0MGQzMDUzNmQyYzhiOWRlMmU0NDdhIn0..ewvdwjyXaPgPczBACG-RnlkLFB32GNMkObEqkJgzWKK4cTWme2cCZ6aCyQYhhSHkQbeqHpP_wtFhBLKYN3L1zalJIgo582TuckRtQLm3kR7e_kzGAK5TFYwDjxdUaURLdQGeRgVRmAHPdlvA6BNpae4iKVmExLSvlkcIXlSGKkYnQHNpN51YpHp2T13PB4lTJYo9PoPOyv-Vf1oRrlhMlr6YFR0jX3jzhZthM-tkSYI3eRCC4uqF22hTD_33VY7j3kwJBtBK9ngdMK-LBftgDtKDWB8wcpfWoOh5bX9l7w9S5dXUuhkF8KlZZWlzToc4c8hjmR2MxsieDfi69QKsOA'}
params = {
    'fields': 'id,title,main_picture,alternative_titles,start_date,end_date,synopsis,mean,rank,popularity,num_list_users,num_scoring_users,nsfw,created_at,updated_at,media_type,status,genres,my_list_status,num_episodes,start_season,broadcast,source,average_episode_duration,rating,pictures,background,related_anime,related_manga,recommendations,studios,statistics,statistics.score_distribution,statistics.status_distribution,statistics.completed_episodes,statistics.plan_to_watch_episodes,statistics.on_hold_episodes,statistics.dropped_episodes,statistics.total_entries,statistics.mean_score',
    'limit' : 1
}

for anime_id in anime_ids:
    try:
        url = f'https://api.myanimelist.net/v2/anime/{anime_id}'
        response = requests.get(url, headers=headers, params=params)
        data = json.loads(response.text)
        anime_details.append(data)

        # Wait 1 seconds for the next request interval
        time.sleep(1)
    except Exception as e:
        print(f"Error retrieving data for anime ID {anime_id}: {e}")

df = pd.json_normalize(anime_details)
df.to_csv('anime_details.csv', index=False)

# %% [markdown]
# # Just download anime_details.csv and continue
# Source: Trust me bro

# %%
df = pd.read_csv('anime_details.csv')
df.tail()
# Out:
#           id                                              title  start_date  \
# 24087  53678                        Ikumonogakari The Animation  2023-03-31
# 24088  43015                              Isaku: Tsumi to Batsu  1999-03-26
# 24089  52630                                              Ke Ai  2018-12-08
# 24090  51763  Tsumamigui The Animation Chance.0: Watashi wo ...  2003-06-27
# 24091  53027                                      Yuwang Jungle  2015-09-05
#
#          end_date                                           synopsis  mean  \
# 24087  2023-05-26  Japan was engulfed in a demographic crisis, fo...   NaN
# 24088  1999-03-26                                                NaN   NaN
# 24089  2018-12-08  A short film that directly gazes at lives and ...   NaN
# 24090  2003-06-27                                                NaN   NaN
# 24091  2015-09-05  An impotent husband, an unsatisfied wife and a...   NaN
#
# ...

# %% [markdown]
# # Dropped the unnecessary columns in anime_details.csv
# Information such as anime start_date, end_date, synopsis, whether is it nsfw, when the data was created and updated, the average_episode_durations, the anime pictures, background, related_anime, related_manga, recommendation, alternative_names, when the anime is being broadcast is deemed irrelevant

# %%
df.drop(['start_date','end_date','synopsis', 'nsfw','created_at','updated_at','average_episode_duration','pictures','background','related_anime','related_manga','recommendations','main_picture.medium','main_picture.large','alternative_titles.synonyms','alternative_titles.en','alternative_titles.ja','broadcast.day_of_the_week','broadcast.start_time'], axis=1, inplace=True)
df.tail()
# Out:
#           id                                              title  mean  rank  \
# 24087  53678                        Ikumonogakari The Animation   NaN   NaN
# 24088  43015                              Isaku: Tsumi to Batsu   NaN   NaN
# 24089  52630                                              Ke Ai   NaN   NaN
# 24090  51763  Tsumamigui The Animation Chance.0: Watashi wo ...   NaN   NaN
# 24091  53027                                      Yuwang Jungle   NaN   NaN
#
#        popularity  num_list_users  num_scoring_users media_type  \
# 24087       12909             853                  0        ova
# 24088       15106             441                101    special
# 24089       19558             133                 42      movie
# 24090       14777             479                 95        ova
# 24091       19721             125                 47      movie
#
#                 status                                             genres  \
# ...

# %% [markdown]
# # Renamed some columns in anime_details.csv

# %%
df.columns = [col.replace('status.', '') for col in df.columns]
df.tail()
# Out:
#           id                                              title  mean  rank  \
# 24087  53678                        Ikumonogakari The Animation   NaN   NaN
# 24088  43015                              Isaku: Tsumi to Batsu   NaN   NaN
# 24089  52630                                              Ke Ai   NaN   NaN
# 24090  51763  Tsumamigui The Animation Chance.0: Watashi wo ...   NaN   NaN
# 24091  53027                                      Yuwang Jungle   NaN   NaN
#
#        popularity  num_list_users  num_scoring_users media_type  \
# 24087       12909             853                  0        ova
# 24088       15106             441                101    special
# 24089       19558             133                 42      movie
# 24090       14777             479                 95        ova
# 24091       19721             125                 47      movie
#
#                 status                                             genres  \
# ...

# %% [markdown]
# # Save the dataframe as anime_details_clean.csv

# %%
df.to_csv('anime_details_cleaned.csv', index=False)

# %%
df = pd.read_csv('anime_details_cleaned.csv')

# %% [markdown]
# # The genres of each anime is stored as a JSON list, which is not useful unless they are 'opened'

# %%
# Create an empty list to store all genre names
genre_names = []

df['genres'] = df['genres'].str.replace("'", '"')

# Loop through each row in the 'genres' column
for genres in df['genres']:
    # Check if the value in the 'genres' column is NaN or float
    if pd.isna(genres):
        # Convert NaN to an empty list
        genres_list = []
    elif isinstance(genres, float):
        # Convert float to an empty list
        genres_list = []
    else:
        # Parse the string into a list of dictionaries using the JSON module
        genres_list = json.loads(genres)
    # Loop through each dictionary in the list and append the 'name' key to the 'genre_names' list
    for genre in genres_list:
        genre_names.append(genre['name'])

# Get a set of unique genre names
unique_genres = set(genre_names)

# Loop through each unique genre name
for genre in unique_genres:
    # Create a new column with the genre name and populate it with True or False values depending on whether the genre is present in the 'genres' column for each row
    df[genre] = df['genres'].apply(lambda x: genre in [g['name'] for g in json.loads(x)] if isinstance(x, str) else False)

# Drop the original 'genres' column
df.drop('genres', axis=1, inplace=True)

# %%
df.to_csv('anime_details_cleaned+genres.csv', index=False)
